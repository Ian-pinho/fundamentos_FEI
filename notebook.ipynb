# %%
arquivo1 = open("arquivo1.txt", "w")
cont=1
for linha in range(0, 1000):
    if cont <= 999:
        arquivo1.write(f"Pares: {cont}\n")
        cont+=2
arquivo1.close()

arquivo1 = open("arquivo2.txt", "w")
cont=0
for linha in range(0, 1000):
    if cont <= 999:
        arquivo1.write(f"Ímpares: {cont}\n")
        cont+=2
arquivo1.close()

# %%
arquivo1 = open("arquivo1.txt", "w")
for linha in range(0, 1000):
    arquivo1.write(f"{linha}\n")
arquivo1.close()
